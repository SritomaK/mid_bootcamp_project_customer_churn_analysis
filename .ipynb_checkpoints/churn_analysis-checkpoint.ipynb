# %%
# Base libraries
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import BASE_COLORS
# %matplotlib inline

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
cust_df_churn = pd.read_excel('Telco_customer_churn.xlsx')
cust_df_loc = pd.read_excel('Telco_customer_churn_location.xlsx')
cust_df_popu = pd.read_excel('Telco_customer_churn_population.xlsx')
cust_df_serv = pd.read_excel('Telco_customer_churn_services.xlsx')
cust_df_status = pd.read_excel('Telco_customer_churn_status.xlsx')
cust_df_demo = pd.read_excel('Telco_customer_churn_demographics.xlsx')

# %%
cust_df_churn.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
cust_df_loc.head()
# Out:
#   Customer ID  Count        Country       State         City  Zip Code  \
# 0  8779-QRDMV      1  United States  California  Los Angeles     90022
# 1  7495-OOKFY      1  United States  California  Los Angeles     90063
# 2  1658-BYGOY      1  United States  California  Los Angeles     90065
# 3  4598-XLKNJ      1  United States  California    Inglewood     90303
# 4  4846-WHAFZ      1  United States  California     Whittier     90602
#
#                  Lat Long   Latitude   Longitude
# 0   34.02381, -118.156582  34.023810 -118.156582
# 1  34.044271, -118.185237  34.044271 -118.185237
# 2  34.108833, -118.229715  34.108833 -118.229715
# 3  33.936291, -118.332639  33.936291 -118.332639
# 4  33.972119, -118.020188  33.972119 -118.020188

# %%
cust_df_popu.head()
# Out:
#    ID  Zip Code  Population
# 0   1     90001       54492
# 1   2     90002       44586
# 2   3     90003       58198
# 3   4     90004       67852
# 4   5     90005       43019

# %%
cust_df_serv.head()
# Out:
#   Customer ID  Count Quarter Referred a Friend  Number of Referrals  \
# 0  8779-QRDMV      1      Q3                No                    0
# 1  7495-OOKFY      1      Q3               Yes                    1
# 2  1658-BYGOY      1      Q3                No                    0
# 3  4598-XLKNJ      1      Q3               Yes                    1
# 4  4846-WHAFZ      1      Q3               Yes                    1
#
#    Tenure in Months    Offer Phone Service  Avg Monthly Long Distance Charges  \
# 0                 1     None            No                               0.00
# 1                 8  Offer E           Yes                              48.85
# 2                18  Offer D           Yes                              11.33
# 3                25  Offer C           Yes                              19.76
# 4                37  Offer C           Yes                               6.33
#
#   Multiple Lines  ... Unlimited Data        Contract  Paperless Billing  \
# ...

# %%
cust_df_status.head()
# Out:
#   Customer ID  Count Quarter  Satisfaction Score Customer Status Churn Label  \
# 0  8779-QRDMV      1      Q3                   3         Churned         Yes
# 1  7495-OOKFY      1      Q3                   3         Churned         Yes
# 2  1658-BYGOY      1      Q3                   2         Churned         Yes
# 3  4598-XLKNJ      1      Q3                   2         Churned         Yes
# 4  4846-WHAFZ      1      Q3                   2         Churned         Yes
#
#    Churn Value  Churn Score  CLTV   Churn Category  \
# 0            1           91  5433       Competitor
# 1            1           69  5302       Competitor
# 2            1           81  3179       Competitor
# 3            1           88  5337  Dissatisfaction
# 4            1           67  2793            Price
#
#                    Churn Reason
# 0  Competitor offered more data
# 1  Competitor made better offer
# 2  Competitor made better offer
# 3     Limited range of services
# ...

# %%
cust_df_demo.head()
# Out:
#   Customer ID  Count  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV      1    Male   78       No            Yes      No         No
# 1  7495-OOKFY      1  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY      1    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ      1  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ      1  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents
# 0                     0
# 1                     1
# 2                     3
# 3                     1
# 4                     1

# %% [markdown]
# ### Merging all the datasets

# %%
cust_df_merged = cust_df_churn.merge(cust_df_demo, left_index=True, right_index=True,
                 how='outer', suffixes=('', '_y'))

cust_df_merged = cust_df_merged.merge(cust_df_loc, left_index=True, right_index=True,
                 how='outer', suffixes=('', '_y'))

cust_df_merged = cust_df_merged.merge(cust_df_serv, left_index=True, right_index=True,
                 how='outer', suffixes=('', '_y'))

cust_df_merged = cust_df_merged.merge(cust_df_status, left_index=True, right_index=True,
                 how='outer', suffixes=('', '_y'))

cust_df_merged = cust_df_merged.merge(cust_df_popu, left_index=True, right_index=True,
                 how='outer', suffixes=('', '_y'))



cust_df_merged.drop(cust_df_merged.filter(regex='_y$').columns.tolist(),axis=1, inplace=True)

# %%
#for reference on how to drop duplicate columns
#https://stackoverflow.com/questions/19125091/pandas-merge-how-to-avoid-duplicating-columns

# %%
cust_df_merged.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ... Monthly Charge  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...          39.65
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...          80.65
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...          95.45
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...          98.50
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...          76.50
#
#   Total Refunds Total Extra Data Charges  Total Long Distance Charges  \
# ...

# %%
cust_df_merged.shape
# Out:
# (7043, 60)

# %%
#our dataset now has 7044 rows and 60 columns

# %% [markdown]
# ## Data Cleaning and Data Wrangling

# %%
cust_df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 60 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CustomerID                         7043 non-null   object
#  1   Count                              7043 non-null   int64
#  2   Country                            7043 non-null   object
#  3   State                              7043 non-null   object
#  4   City                               7043 non-null   object
#  5   Zip Code                           7043 non-null   int64
#  6   Lat Long                           7043 non-null   object
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Gender                             7043 non-null   object
#  10  Senior Citizen                     7043 non-null   object
# ...

# %%
#Total charges data type is object. changing it to float


cust_df_merged["Total Charges"] = cust_df_merged["Total Charges"].apply(pd.to_numeric, errors="coerce")

# %%
cust_df_merged['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
# checking for NaN values. No null values except In column 'Churn Reason'

cust_df_merged.isnull().sum()
# Out:
# CustomerID                              0
# Count                                   0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Lat Long                                0
# Latitude                                0
# Longitude                               0
# Gender                                  0
# Senior Citizen                          0
# Partner                                 0
# Dependents                              0
# Tenure Months                           0
# Phone Service                           0
# Multiple Lines                          0
# Internet Service                        0
# Online Security                         0
# Online Backup                           0
# Device Protection                       0
# Tech Support                            0
# Streaming TV                            0
# ...

# %%
cust_df_merged.groupby(['Churn Category'])['CustomerID'].count()
# Out:
# Churn Category
# Attitude           314
# Competitor         841
# Dissatisfaction    303
# Other              200
# Price              211
# Name: CustomerID, dtype: int64

# %%
# Column 'Churn Category' has 5174 null values because those are the customers who did not churn

# %%
#filling the null values in Column 'Churn Category' with NA
cust_df_merged['Churn Category'] = cust_df_merged['Churn Category'].fillna("NA")

# %%
cust_df_merged.groupby(['Churn Category'])['CustomerID'].count()
# Out:
# Churn Category
# Attitude            314
# Competitor          841
# Dissatisfaction     303
# NA                 5174
# Other               200
# Price               211
# Name: CustomerID, dtype: int64

# %%
# dropping tmore columns

cust_df_merged =  cust_df_merged.drop(['Quarter', 'Number of Dependents'], axis=1)

# %%
#checking for duplicates in the column 'Customer ID'. no duplicates found, so we have 7043 unique customer entries.
print(cust_df_merged['CustomerID'].duplicated().sum())
# Out:
# 0

# %%
# dropping the columns which are clearly not relevant for our analysis.dropping churn reason because it is covered by churn category.

cust_df_merged =  cust_df_merged.drop(['Count', 'Country', 'State', 'Lat Long', 'Latitude', 'Customer ID', 'ID','Customer ID', 'Longitude', 'Churn Reason'], axis=1)

# %%
cust_df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 49 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CustomerID                         7043 non-null   object
#  1   City                               7043 non-null   object
#  2   Zip Code                           7043 non-null   int64
#  3   Gender                             7043 non-null   object
#  4   Senior Citizen                     7043 non-null   object
#  5   Partner                            7043 non-null   object
#  6   Dependents                         7043 non-null   object
#  7   Tenure Months                      7043 non-null   int64
#  8   Phone Service                      7043 non-null   object
#  9   Multiple Lines                     7043 non-null   object
#  10  Internet Service                   7043 non-null   object
# ...

# %%
cust_df_merged.isnull().sum()
# Out:
# CustomerID                              0
# City                                    0
# Zip Code                                0
# Gender                                  0
# Senior Citizen                          0
# Partner                                 0
# Dependents                              0
# Tenure Months                           0
# Phone Service                           0
# Multiple Lines                          0
# Internet Service                        0
# Online Security                         0
# Online Backup                           0
# Device Protection                       0
# Tech Support                            0
# Streaming TV                            0
# Streaming Movies                        0
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charges                         0
# Total Charges                          11
# ...

# %%
cust_df_merged.groupby(['Population'])['CustomerID'].count()
# Out:
# Population
# 11.0        1
# 13.0        1
# 16.0        1
# 19.0        1
# 21.0        2
#            ..
# 97318.0     1
# 98239.0     1
# 101215.0    1
# 103214.0    1
# 105285.0    1
# Name: CustomerID, Length: 1607, dtype: int64

# %%
# dropping more columns

cust_df_merged =  cust_df_merged.drop(['Population'], axis=1)

# %%
# replacing null values in the column Total Charges with the mean

cust_df_merged['Total Charges'].fillna(cust_df_merged['Total Charges'].mean(), inplace=True)

# %%
cust_df_merged.isnull().sum()
# Out:
# CustomerID                           0
# City                                 0
# Zip Code                             0
# Gender                               0
# Senior Citizen                       0
# Partner                              0
# Dependents                           0
# Tenure Months                        0
# Phone Service                        0
# Multiple Lines                       0
# Internet Service                     0
# Online Security                      0
# Online Backup                        0
# Device Protection                    0
# Tech Support                         0
# Streaming TV                         0
# Streaming Movies                     0
# Contract                             0
# Paperless Billing                    0
# Payment Method                       0
# Monthly Charges                      0
# Total Charges                        0
# Churn Label                          0
# Churn Value                          0
# ...

# %%
# round(customer_data.isna().sum()/len(customer_data),4)*100  # shows the percentage of null values in a column
# nulls_df = pd.DataFrame(round(customer_data.isna().sum()/len(customer_data),4)*100)
# nulls_df
# nulls_df = nulls_df.reset_index()
# nulls_df
# nulls_df.columns = ['header_name', 'percent_nulls']
# nulls_df

# %%
# Drop missing values
# df.dropna(inplace=True)

# %%
cust_df_merged.shape
# Out:
# (7043, 48)

# %%
#snake column names
cols = []
for i in range(len(cust_df_merged.columns)):
    cols.append(cust_df_merged.columns[i].lower().replace(' ', '_'))
cust_df_merged.columns = cols

print(cust_df_merged.columns)
# Out:
# Index(['customerid', 'city', 'zip_code', 'gender', 'senior_citizen', 'partner',
#        'dependents', 'tenure_months', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method', 'monthly_charges',
#        'total_charges', 'churn_label', 'churn_value', 'churn_score', 'cltv',
#        'age', 'under_30', 'married', 'referred_a_friend',
#        'number_of_referrals', 'tenure_in_months', 'offer',
#        'avg_monthly_long_distance_charges', 'internet_type',
#        'avg_monthly_gb_download', 'device_protection_plan',
#        'premium_tech_support', 'streaming_music', 'unlimited_data',
#        'monthly_charge', 'total_refunds', 'total_extra_data_charges',
#        'total_long_distance_charges', 'total_revenue', 'satisfaction_score',
#        'customer_status', 'churn_category'],
#       dtype='object')

# %%
#dropping customerid
cust_df_merged =  cust_df_merged.drop(['customerid'], axis=1)

# %%
print(cust_df_merged.columns)
# Out:
# Index(['city', 'zip_code', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure_months', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges', 'churn_label',
#        'churn_value', 'churn_score', 'cltv', 'age', 'under_30', 'married',
#        'referred_a_friend', 'number_of_referrals', 'tenure_in_months', 'offer',
#        'avg_monthly_long_distance_charges', 'internet_type',
#        'avg_monthly_gb_download', 'device_protection_plan',
#        'premium_tech_support', 'streaming_music', 'unlimited_data',
#        'monthly_charge', 'total_refunds', 'total_extra_data_charges',
#        'total_long_distance_charges', 'total_revenue', 'satisfaction_score',
#        'customer_status', 'churn_category'],
#       dtype='object')

# %%
cust_df_merged.head()
# Out:
#           city  zip_code  gender senior_citizen partner dependents  \
# 0  Los Angeles     90003    Male             No      No         No
# 1  Los Angeles     90005  Female             No      No        Yes
# 2  Los Angeles     90006  Female             No      No        Yes
# 3  Los Angeles     90010  Female             No     Yes        Yes
# 4  Los Angeles     90015    Male             No      No        Yes
#
#    tenure_months phone_service multiple_lines internet_service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   streaming_music unlimited_data monthly_charge total_refunds  \
# 0              No             No          39.65          0.00
# ...

# %%
cust_df_merged['city'].value_counts()
# Out:
# Los Angeles       305
# San Diego         150
# San Jose          112
# Sacramento        108
# San Francisco     104
#                  ...
# Healdsburg          4
# Jenner              4
# Philo               4
# Point Arena         4
# Olympic Valley      4
# Name: city, Length: 1129, dtype: int64

# %%
cust_df_merged['tenure_months'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure_months, Length: 73, dtype: int64

# %%
#keeping all the remaining columns for exploratory data analysis

# %%
#plotting the categorical columns for visualization
for column in cust_df_merged.columns:
    if cust_df_merged[column].dtype == 'object':
        plt.figure(figsize=(10, 6))
        sns.countplot(x=column, data=cust_df_merged, order=cust_df_merged[column].value_counts().index)
        plt.title(f'Unique Values Count for {column}')
        plt.show()

# %%
#plotting the numerical columns for visualization
for column in cust_df_merged.columns:
    if cust_df_merged[column].dtype != 'object':
        plt.figure(figsize=(8, 4))
        sns.histplot(cust_df_merged[column], bins=20, kde=True)
        plt.title(f'Distribution of Values for {column}')
        plt.show()

# %%
# Target column is churn_label. Plotting the column to get a overview of the data in the column
#sns.countplot(x='churn_label', data=customer_data)

# %%
cust_df_merged.to_excel('cust_df_merged.xlsx', index=False)

# %% [markdown]
# ### What is the overall churn rate for the company?

# %%
churn_label_count = cust_df_merged['churn_label'].value_counts()

plt.figure(figsize=(7, 4), dpi=100)
plt.pie(churn_label_count, autopct="%.2f%%", labels=churn_label_count.index, explode=[0, 0.1])
plt.title("Percentage of Customers Churned")
plt.show()

# %%
# this shows that 26.54% of customers churned

# %% [markdown]
# ## Customer Segmentation

# %%
# analysing customer demogrphic info

# %% [markdown]
# ### Gender Distribution

# %%
# Gender Distribution- also donme in tableau

gender_distribution = cust_df_merged['gender'].value_counts()

plt.figure(figsize=(7, 4), dpi=100)
plt.bar(gender_distribution.index, gender_distribution, color=['blue', 'pink'])
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
# almost half of the custonmer population is Male and other half is Female

# %%
# relationship between Gender and Customer Churn 

sns.countplot(x='gender', hue='churn_label', data=cust_df_merged)
plt.title('Gender vs Churn')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ### Marital Distribution

# %%
#also done in tableau
married_distribution = cust_df_merged['married'].value_counts()

plt.figure(figsize=(7, 4), dpi=100)
plt.bar(married_distribution.index, married_distribution, color=['green', 'red'])
plt.title("Marital Distribution")
plt.xlabel("Married")
plt.ylabel("Count")
plt.show()

# %%
# relationship between Marital Status and Customer Churn 

sns.countplot(x='married', hue='churn_label', data=cust_df_merged)
plt.title('Married vs Churn')
plt.xlabel('Married')
plt.ylabel('Number of Customers')
plt.show()

# %%
# most of the cutomer population is married

# %% [markdown]
# ### Senior Citizen

# %%
# done in Tableau

# %%
# relationship between Senior Citizen and Customer Churn 

sns.countplot(x='senior_citizen', hue='churn_label', data=cust_df_merged)
plt.title('Senior Citizen vs Churn')
plt.xlabel('Senior Citizen')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ### Age

# %%
min_age, max_age, average_age = cust_df_merged['age'].agg(['min', 'max', 'mean'])

# %%
min_age, max_age, average_age
# Out:
# (19.0, 80.0, 46.50972596904728)

# %%
#Age distribution done in Tableau

# %%
# relationship between Age and Customer Churn 

plt.figure(figsize=(12, 6))
sns.countplot(x=pd.cut(cust_df_merged['age'], bins=np.arange(15, 101, 15)), hue='churn_label', data=cust_df_merged)
plt.title('Age vs Churn')
plt.xlabel('Age Bins')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ### Dependents

# %%
# relationship between Dependents and Customer Churn 

sns.countplot(x='dependents', hue='churn_label', data=cust_df_merged)
plt.title('Dependents vs Churn')
plt.xlabel('Dependents')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# # Services Analysis

# %%
cust_df_merged.describe()
# Out:
#            zip_code  tenure_months  monthly_charges  total_charges  \
# count   7043.000000    7043.000000      7043.000000    7043.000000
# mean   93521.964646      32.371149        64.761692    2283.300441
# std     1865.794555      24.559481        30.090047    2265.000258
# min    90001.000000       0.000000        18.250000      18.800000
# 25%    92102.000000       9.000000        35.500000     402.225000
# 50%    93552.000000      29.000000        70.350000    1400.550000
# 75%    95351.000000      55.000000        89.850000    3786.600000
# max    96161.000000      72.000000       118.750000    8684.800000
#
#        churn_value  churn_score         cltv          age  \
# count  7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.265370    58.699418  4400.295755    46.509726
# std       0.441561    21.525131  1183.057152    16.750352
# min       0.000000     5.000000  2003.000000    19.000000
# 25%       0.000000    40.000000  3469.000000    32.000000
# ...

# %%
# Internet service

internet_services = cust_df_merged['internet_service'].value_counts()

plt.figure(figsize=(7, 4), dpi=100)
plt.bar(internet_services.index, internet_services)
plt.title("Internet Services Distribution")
plt.xlabel("Type of Internet Service")
plt.ylabel("Count")
plt.show()

# %%
# Three-fourths of the customers have chosen to use internet services through either Fiber Optic or DSL connections

# %%
# relationship between internet service and Customer Churn 
plt.figure(figsize=(12, 6))
sns.histplot(data=cust_df_merged, x='internet_service', hue='churn_label', multiple='stack', bins=30, palette='pastel')
plt.title('Distribution of Internet Servive vs Churn')
plt.xlabel('Internet Service')
plt.ylabel('Number of Customers')
plt.show()

# %%
# customers using the Fiber Optic Internet Service have the highest tendency to churn

# %%
#Phone Service
cust_df_merged['phone_service'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: phone_service, dtype: int64

# %%
phone_services = cust_df_merged['phone_service'].value_counts()

plt.figure(figsize=(7, 4), dpi=100)
plt.bar(phone_services.index, phone_services, color=['blue', 'orange'])
plt.title("Phone Service Distribution")
plt.xlabel("Phone Service")
plt.ylabel("Count")
plt.show()

# %%
# relationship between phone service and Customer Churn 
plt.figure(figsize=(12, 6))
sns.histplot(data=cust_df_merged, x='phone_service', hue='churn_label', multiple='stack', bins=30, palette='pastel')
plt.title('Distribution of Phone Service vs Churn')
plt.xlabel('Phone Service')
plt.ylabel('Number of Customers')
plt.show()

# %%
# relationship between tech support and Customer Churn 
plt.figure(figsize=(12, 6))
sns.histplot(data=cust_df_merged, x='tech_support', hue='churn_label', multiple='stack', bins=30, palette='pastel')
plt.title('Distribution of Tech Support vs Churn')
plt.xlabel('Tech Support')
plt.ylabel('Number of Customers')
plt.show()

# %%
#customers who have not opted for the tech support service have higher tendency to churn

# %%
# relationship between Offer and Customer Churn 
plt.figure(figsize=(12, 6))
sns.histplot(data=cust_df_merged, x='offer', hue='churn_label', multiple='stack', bins=30, palette='pastel')
plt.title('Distribution of Offer vs Churn')
plt.xlabel('Offer')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# # Churn Analysis

# %%
cust_df_merged["churn_label"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: churn_label, dtype: int64

# %%
# Total of 1869 customers churned

# %%
# Analysing the churn reason
sns.countplot(x='churn_category', data=cust_df_merged)
plt.xticks(rotation=45, ha='right')
plt.figure(figsize=(10, 6))
plt.show()

# %%
# NA are the customers who did not churn
# from the above graph it is evident that the primary reason for customer churn is the availability of a competitor offering better prices and services.

# %% [markdown]
# ## Customer Account Analysis

# %% [markdown]
# ### relationship between Monthly charge and Total Charge and Customer Churn

# %%
# relationship between Monthly charge and Total Charge and Customer Churn

sns.scatterplot(x='monthly_charges', y='total_charges', data=cust_df_merged, hue="churn_label")
plt.xlabel('Monthly Charges')
plt.ylabel('Total Charges')
plt.show()

# %%
sns.pairplot(cust_df_merged, hue="churn_label", vars=['monthly_charges', 'total_charges'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=cust_df_merged, x='monthly_charges', hue='churn_label', multiple='stack', bins=30, palette='pastel')
plt.title('Monthly Charges vs Churn')
plt.xlabel('Monthly Charges')
plt.ylabel('Number of Customers')
plt.show()

# %%
#In the pair plot, it is noticeable that a significant number of customers churned when their monthly bills increased. On the other hand, a considerable proportion of customers opted to stay even when their total charges were on the rise.

# %% [markdown]
# ### relationship between Contract type and Customer Churn

# %%
# relationship between Contract type and Customer Churn 

sns.countplot(x='contract', hue='churn_label', data=cust_df_merged)
plt.title('Contract vs Churn')
plt.xlabel('Contract')
plt.ylabel('Number of Customers')
plt.show()

# %%
sns.countplot(x='contract', data=cust_df_merged)
plt.figure(figsize=(10, 6))
plt.show()

# %%
# We noticed that the longer the contract duration, the lower the churn rate. 
#Customers who choose longer contracts are less likely to leave, possibly because those on monthly contracts pay more. In contrast, longer-term customers often get discounts, making them more likely to stay.

# %% [markdown]
# ### relationship between PaperlessBilling an Churn

# %%
sns.countplot(x='paperless_billing', hue='churn_label', data=cust_df_merged)
plt.title('Paperless Billing vs Churn')
plt.xlabel('Paperless Billing')
plt.ylabel('Number of Customers')
plt.show()

# %%
# people opting for paperless billing show higher tendency to churn

# %% [markdown]
# ### Relationship between Payment Method an Churn

# %%
sns.countplot(x='payment_method', hue='churn_label', data=cust_df_merged)
plt.title('Payment Method vs Churn')
plt.xlabel('Payment Method')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# people opting for Electronic check mode of payment are more likey to churn

# %% [markdown]
# ### Relationship between tenure and Customer Churn

# %%
# Create a histogram of the Tenure column
plt.hist(cust_df_merged['tenure_months'], bins=20, color='blue')
plt.xlabel('Tenure (months)')
plt.ylabel('Frequency')
plt.show()

# %%
# The graph shows that many new customers are signing up for the company's services. Most of them stay around for about 74 months before churning.

# %%
# relationship between tenure and Customer Churn 
plt.figure(figsize=(12, 6))
sns.histplot(data=cust_df_merged, x='tenure_months', hue='churn_label', multiple='stack', bins=30, palette='pastel')
plt.title('Distribution of Tenure vs Churn')
plt.xlabel('Tenure (Months)')
plt.ylabel('Number of Customers')
plt.show()

# %%
# The graph suggests that a majority of customers tend to churn within the initial months of their tenure, indicating a higher likelihood of churn among new customers.

# %% [markdown]
# ### Exploring relationship between Monthly Charges, Tenure with Churn

# %%
plt.figure(figsize=(10, 6))

# Box plot for 'tenure' and 'monthly charges' against churn
sns.boxplot(x='churn_label', y='tenure_months', data=cust_df_merged, hue='churn_label', width=0.4, dodge=True)
sns.boxplot(x='churn_label', y='monthly_charges', data=cust_df_merged, hue='churn_label', width=0.4, dodge=True)
plt.title('Comparison of Tenure and Monthly Charges for Churned and Not Churned Customers')
plt.xlabel('Churn')
plt.ylabel('Value')
plt.show()

# %%
from matplotlib.ticker import MultipleLocator

fig, axes = plt.subplots(ncols=2, figsize=(12, 4), sharey=True)

# Features of interest
selected_features = ['monthly_charges', 'tenure_months']

for i, feature in enumerate(selected_features):
    sns.boxplot(x=feature, y='churn_label', data= cust_df_merged, ax=axes.flat[i])

    if i == 0:
        axes.flat[i].xaxis.set_major_locator(MultipleLocator(10))
    else:
        axes.flat[i].xaxis.set_major_locator(MultipleLocator(20))

    axes.flat[i].set_ylabel('')

fig.suptitle('Churn distribution in Monthly Charges and Tenure')
fig.align_labels()
plt.show()

# %% [markdown]
# ### relationship between cltv and churn

# %%
# relationship between cltv and churn

# Convert 'churn_label' to binary (1 for churned, 0 for not churned)
cust_df_merged['churn_binary'] = cust_df_merged['churn_label'].apply(lambda x: 1 if x == 'Yes' else 0)

# Basic analysis: average CLV for churned and not churned customers
average_clv_churned = cust_df_merged[cust_df_merged['churn_binary'] == 1]['cltv'].mean()
average_clv_not_churned = cust_df_merged[cust_df_merged['churn_binary'] == 0]['cltv'].mean()

# Print the results
print(f"Average CLV for churned customers: {average_clv_churned}")
print(f"Average CLV for not churned customers: {average_clv_not_churned}")

# Plot the results
plt.bar(['Churned', 'Not Churned'], [average_clv_churned, average_clv_not_churned])
plt.xlabel('Churn Status')
plt.ylabel('Average CLV')
plt.title('Relationship between CLV and Churn')
plt.show()
# Out:
# Average CLV for churned customers: 4149.414660246121
# Average CLV for not churned customers: 4490.921337456513

# %%
#Given the higher CLV for not churned customers, it might be worthwhile to focus on customer retention efforts. This could involve improving customer satisfaction, providing better customer support, or implementing loyalty programs to encourage repeat business.

# %%
cust_df_merged.head()
# Out:
#           city  zip_code  gender senior_citizen partner dependents  \
# 0  Los Angeles     90003    Male             No      No         No
# 1  Los Angeles     90005  Female             No      No        Yes
# 2  Los Angeles     90006  Female             No      No        Yes
# 3  Los Angeles     90010  Female             No     Yes        Yes
# 4  Los Angeles     90015    Male             No      No        Yes
#
#    tenure_months phone_service multiple_lines internet_service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   unlimited_data monthly_charge total_refunds total_extra_data_charges  \
# 0             No          39.65          0.00                       20
# ...

# %% [markdown]
# ### Cohort Analysis to Understand Trend of Churn vs CLTV over Tenure

# %%
# Create cohorts based on the acquisition month
cohorts = cust_df_merged.groupby(['tenure_months', 'churn_binary'])

# Calculate the average CLV for each cohort over time
average_clv_by_cohort = cohorts['cltv'].mean().unstack()

# Plot the cohort analysis
plt.figure(figsize=(12, 6))
for churn_status in average_clv_by_cohort.columns:
    plt.plot(average_clv_by_cohort.index, average_clv_by_cohort[churn_status], marker='o', label=f'Churn {churn_status}')

plt.xlabel('Months from Acquisition')
plt.ylabel('Average CLV')
plt.title('Cohort Analysis of Average CLV Over Time by Churn Status')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a line plot to show the trend
plt.figure(figsize=(12, 6))
sns.lineplot(x='tenure_months', y='cltv', hue='churn_binary', data=cust_df_merged, errorbar=None)
plt.xlabel('Tenure Months')
plt.ylabel('Customer Lifetime Value (CLTV)')
plt.title('Trend of Churn vs. CLTV over Tenure Months')
plt.legend(title='Churn', loc='upper right', labels=['Not Churned', 'Churned'])
plt.show()

# %%
#Do the customers who stay(dont churn) have higher customer life time value?

# %% [markdown]
# ### Null Hypothesis (H0): The median Customer Lifetime Value (CLTV) for not churned customers is equal to or less than the median CLTV for churned customers.
#
# ### Alternative Hypothesis (H1): The median Customer Lifetime Value (CLTV) for not churned customers is significantly higher than the median CLTV for churned customers.

# %%
#plotting  boxplot to find out
plt.figure(figsize=(10, 6))
sns.boxplot(x='churn_label', y='cltv', data=cust_df_merged)
plt.title('CLTV Comparison for Churned and Not Churned Customers')
plt.xlabel('Churn')
plt.ylabel('Customer Lifetime Value (CLTV)')
plt.show()

# %% [markdown]
# ### From the box plot we can see CLTV for the churned cutomers is 4300 and the median for the customers who did not churn is 4600. Hence we can reject the null hypothesis.

# %%
# its clear from the box plot that the customer who churn (in yellow) have lower cltv and cutomers who stay have higher cltv

#Hypothesis Testing:
#Formulate hypotheses about the differences in CLTV and test them. For example, you might hypothesize that the median CLTV for not churned customers is significantly higher than that for churned customers.

# Time-Based Analysis:
# Analyze CLTV trends over time. Examine how CLTV changes for customers who stay and those who churn across different periods or cohorts. This can help identify trends or patterns in customer behavior.

# Correlation Analysis:
# Explore correlations between CLTV and other relevant metrics or features in your dataset. For example, you might investigate if there is a correlation between CLTV and customer satisfaction scores, monthly charges, or other variables.

# Predictive Modeling:
# Build predictive models to estimate CLTV and assess the factors that contribute to customer churn. Machine learning models, such as regression or classification models, can help identify key predictors of CLTV and churn.

# %% [markdown]
# ## SQL connection

# %%
from sqlalchemy import create_engine
import getpass

# %%
password = getpass.getpass('Enter database password: ')
# Out:
# Enter database password: ········

# %%
database_name = 'Ironhack'

# %%
engine = create_engine(f'mysql+pymysql://root:{password}@localhost/{database_name}')

# %%
cust_df_merged.to_sql('Telco_Customer_Churn', con=engine, index=False, if_exists='replace')
# Out:
# 7043

# %%
#retrieving

query = "SELECT * FROM Telco_Customer_Churn"
cust_df_merg = pd.read_sql(query, engine)

# %%
cust_df_merg.head()
# Out:
#           city  zip_code  gender senior_citizen partner dependents  \
# 0  Los Angeles     90003    Male             No      No         No
# 1  Los Angeles     90005  Female             No      No        Yes
# 2  Los Angeles     90006  Female             No      No        Yes
# 3  Los Angeles     90010  Female             No     Yes        Yes
# 4  Los Angeles     90015    Male             No      No        Yes
#
#    tenure_months phone_service multiple_lines internet_service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   unlimited_data monthly_charge total_refunds total_extra_data_charges  \
# 0             No          39.65          0.00                       20
# ...

# %% [markdown]
# ## Plotting the Correlation between Churn and other Features

# %%
# extracting relevant columns
# specifying the columns to extract
selected_columns = ['gender', 'dependents','senior_citizen', 'tenure_months', 'phone_service', 'internet_service', 
                     'tech_support', 'contract', 'paperless_billing', 'payment_method', 
                     'monthly_charges', 'churn_label', 'married', 'cltv']

new_cust_df = cust_df_merg.loc[:, selected_columns].copy()

# %%
new_cust_df
# Out:
#       gender dependents senior_citizen  tenure_months phone_service  \
# 0       Male         No             No              2           Yes
# 1     Female        Yes             No              2           Yes
# 2     Female        Yes             No              8           Yes
# 3     Female        Yes             No             28           Yes
# 4       Male        Yes             No             49           Yes
# ...      ...        ...            ...            ...           ...
# 7038  Female         No             No             72           Yes
# 7039    Male        Yes             No             24           Yes
# 7040  Female        Yes             No             72           Yes
# 7041  Female        Yes             No             11            No
# 7042    Male         No             No             66           Yes
#
#      internet_service         tech_support        contract paperless_billing  \
# ...

# %%
new_cust_df['churn_label'] = new_cust_df['churn_label'].replace({'No': 0, 'Yes': 1})
df_dummies = pd.get_dummies(new_cust_df)
df_dummies.head()
# Out:
#    tenure_months  monthly_charges  churn_label  cltv  gender_Female  \
# 0              2            53.85            1  3239              0
# 1              2            70.70            1  2701              1
# 2              8            99.65            1  5372              1
# 3             28           104.80            1  5003              1
# 4             49           103.70            1  5340              0
#
#    gender_Male  dependents_No  dependents_Yes  senior_citizen_No  \
# 0            1              1               0                  1
# 1            0              0               1                  1
# 2            0              0               1                  1
# 3            0              0               1                  1
# 4            1              0               1                  1
#
#    senior_citizen_Yes  ...  contract_One year  contract_Two year  \
# 0                   0  ...                  0                  0
# ...

# %%
#for reference
#https://matplotlib.org/3.1.1/api/cm_api.html#matplotlib.cm.get_cmap
#https://stackoverflow.com/questions/73918175/how-to-plot-correlation-between-two-columns?rq=3

# %%
fig, ax = plt.subplots()
colormap = plt.get_cmap('plasma')
churn_corr_dummies = df_dummies.corr()['churn_label'].sort_values(ascending=False)
churn_corr_dummies[1:].plot(kind='bar',
                            color=colormap(np.linspace(0, 1,len(churn_corr_dummies))),
                            ax=ax)
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.set_title('Churn correlation with each feature')
plt.show()
